# %%
from __future__ import print_function
from __future__ import absolute_import

# %matplotlib inline

import numpy
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Modeling Exercise
#
# This exercise is designed to both help you to learn `git` and `github` as well as some concepts from modeling that will be important.  If you need some ideas take a look at the [course notes](http://github.com/mandli/intro-numerical-methods).

# %% [markdown]
# ## Reading Data
#
# Take the data you read in from `get_hydro_data.ipynb` and write a function that read in the stream flow data and precip and returns the data

# %%
def read_streamflow_data(path):
    data = pd.read_csv(path)
    return data

streamflow_data = read_streamflow_data("./temp_data/streamflow_data.csv")
precip_data = read_streamflow_data("./temp_data/precip_data.csv")
# Out:
#               time_stamps   17611097   17611065   17611807   17611043  \
# 0    2018-01-01T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# 1    2018-01-02T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# 2    2018-01-03T00:00:00Z   1.388920   1.036183   1.358902   1.089474
# 3    2018-01-04T00:00:00Z   6.494460   5.648786   6.479451   5.257894
# 4    2018-01-05T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# 5    2018-01-06T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# 6    2018-01-07T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# 7    2018-01-08T00:00:00Z  76.762890  56.142352  75.036882  59.234202
# 8    2018-01-09T00:00:00Z  54.773413  40.210641  53.617738  42.080256
# 9    2018-01-10T00:00:00Z   0.500000   0.388060   0.500000   0.344737
# 10   2018-01-11T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# 11   2018-01-12T00:00:00Z   0.000000   0.000000   0.000000   0.000000
# ...

# %%
precip_values = precip_data['17611097'].values
precip_timesteps = pd.to_datetime(precip_data['time_stamps'].values)

streamflow_values = streamflow_data['X_00060_00000'].values
streamflow_timesteps = pd.to_datetime(streamflow_data['dateTime'].values)
streamflow_timesteps
# Out:
# DatetimeIndex(['2017-12-01 08:00:00+00:00', '2017-12-01 08:15:00+00:00',
#                '2017-12-01 08:30:00+00:00', '2017-12-01 08:45:00+00:00',
#                '2017-12-01 09:00:00+00:00', '2017-12-01 09:15:00+00:00',
#                '2017-12-01 09:30:00+00:00', '2017-12-01 09:45:00+00:00',
#                '2017-12-01 10:00:00+00:00', '2017-12-01 10:15:00+00:00',
#                ...
#                '2018-05-02 04:30:00+00:00', '2018-05-02 04:45:00+00:00',
#                '2018-05-02 05:00:00+00:00', '2018-05-02 05:15:00+00:00',
#                '2018-05-02 05:30:00+00:00', '2018-05-02 05:45:00+00:00',
#                '2018-05-02 06:00:00+00:00', '2018-05-02 06:15:00+00:00',
#                '2018-05-02 06:30:00+00:00', '2018-05-02 06:45:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=14588, freq=None)

# %% [markdown]
# ## Plot the Data
#
# Now write a function that plots the data you read in from above.

# %%
def plot_streamflow_data(x, y):
    plt.plot(x,y)
    
plot_streamflow_data(streamflow_timesteps, streamflow_values)



def plot_stream_precip (x_stream, y_stream, x_precip, y_precip, col_stream, col_precip, x_labels , y_labels, labels):
    plt.plot(x_stream, y_stream, color = col_stream, label = labels[0], ls = '--')
    plt.xlabel(x_labels[0])
    plt.ylabel(y_labels[0])

    
    plt.plot(x_precip, y_precip, color = col_precip, label = labels[1])
    plt.ylabel(y_labels[1])
    
    plt.legend()
    
xlabels = ['Time','Time']
ylabels = ['Streamflow','precipitation']
labels = ['steramflow','precipitation']
plot_stream_precip(streamflow_timesteps, streamflow_values, precip_timesteps, precip_values, "red", "blue", xlabels, ylabels,labels)

# %% [markdown]
# ## Make a Model
#
# Write a function that takes the data from above and fits a curve to it.  Justify your approach to this problem as well.

# %%
def fit_streamflow_data(x, y):
    plot
    
    pass

# %% [markdown]
# ## Pull It All Together
#
# Use all three functions above and make a prediction where there is no data.  Think about where your prediction may be valid or invalid.  Make sure to mention this in your `doc-string`.

# %%
def streamflow_prediction(x, y):
    """"""
    
    pass
